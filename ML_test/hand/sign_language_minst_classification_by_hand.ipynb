# %%
import numpy as np

# %%
dataset = np.load('sign_mnist.npz')
x_train, y_train = dataset['x_train'], dataset['y_train']
x_test, y_test = dataset['x_test'], dataset['y_test']

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (27455, 28, 28)
# (27455,)
# (7172, 28, 28)
# (7172,)

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 10, figsize=(10, 13),
                        subplot_kw = {'xticks': [], 'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(x_test[i], cmap = 'gray')
    ax.set_title(str(i) + ': ?')
plt.show()

# %%
import numpy as np

# %%
y_pred = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
np.savetxt('hand_y_pred.csv', y_pred, fmt='%c')

# %%
fig, axes = plt.subplots(nrows = 10, ncols = 10, figsize = (10, 13),
                         subplot_kw = {'xticks': [], 'yticks': []})

alphabat = 'abcdefghijklmnopqrstuvwxyz'

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = alphabat[y_train[i]]
    ax.set_title(title)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 10, figsize= (10, 13),
                        subplot_kw = {'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(x_test[i], cmap = 'gray')
    ax.set_title(str(i) + ': ?')
plt.show()

# %%
import numpy as np

# %%
y_pred = ['g', 'f', 'k', 'a', 'd', 'y', 'k', 'o', 'd', 'h']
np.savetxt('hand_y_pred.csv', y_pred, fmt='%c')
